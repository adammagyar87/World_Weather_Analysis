# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
cities
# Out:
# ['vanimo',
#  'mount isa',
#  'one hundred mile house',
#  'saint-pierre',
#  'hilo',
#  'ngukurr',
#  'taolanaro',
#  'zhuji',
#  'libreville',
#  'ushuaia',
#  'chany',
#  'kidal',
#  'nizwa',
#  'mahebourg',
#  'lata',
#  'hithadhoo',
#  'san rafael',
#  'albany',
#  'espanola',
#  'lorengau',
#  'norman wells',
#  'bluff',
#  'klaksvik',
#  'jamestown',
#  'puerto madero',
#  'hobart',
#  'east london',
#  'puerto ayora',
#  'saskylakh',
#  'waipawa',
#  'port elizabeth',
#  'codrington',
#  'angra',
#  'bengkulu',
#  'touros',
#  'barrow',
#  'bilma',
#  'sadiqabad',
#  'cape town',
#  'belushya guba',
#  'bredasdorp',
#  'butaritari',
#  'moba',
#  'atuona',
#  'khatanga',
#  'college',
#  'punta arenas',
#  'necochea',
#  'arman',
#  'dubki',
#  'victoria',
#  'steenwijk',
#  'castro',
#  'dikson',
#  'grand river south east',
#  'shubarkuduk',
#  'erenhot',
#  'cherskiy',
#  'provideniya',
#  'nhulunbuy',
#  'busselton',
#  'inderborskiy',
#  'nanortalik',
#  'kaitangata',
#  'grande-riviere',
#  'ha tinh',
#  'arraial do cabo',
#  'bay roberts',
#  'illoqqortoormiut',
#  'wagga wagga',
#  'narsaq',
#  'sinnamary',
#  'iqaluit',
#  'iberia',
#  'chokurdakh',
#  'talnakh',
#  'kamenskoye',
#  'kodiak',
#  'concordia',
#  'san patricio',
#  'georgetown',
#  'nome',
#  'nizhneyansk',
#  'palmas bellas',
#  'mataura',
#  'qaanaaq',
#  'upernavik',
#  'sentyabrskiy',
#  'mys shmidta',
#  'penzance',
#  'luderitz',
#  'lasa',
#  'saint-philippe',
#  'ponta do sol',
#  'hobyo',
#  'cidreira',
#  'nicoya',
#  'fairbanks',
#  'borgarnes',
#  'dujuma',
#  'barentsburg',
#  'ola',
#  'tiksi',
#  'palabuhanratu',
#  'lebu',
#  'yellowknife',
#  'mayumba',
#  'vaini',
#  'eyl',
#  'severo-kurilsk',
#  'kamaishi',
#  'kahului',
#  'batouri',
#  'caraballeda',
#  'hofn',
#  'kozhva',
#  'nikolskoye',
#  'ancud',
#  'praia da vitoria',
#  'san cristobal',
#  'umm lajj',
#  'vanavara',
#  'faya',
#  'coos bay',
#  'kapaa',
#  'kalanguy',
#  'saint anthony',
#  'portland',
#  'hermanus',
#  'khasan',
#  'sataua',
#  'lerwick',
#  'bubaque',
#  'mar del plata',
#  'tasiilaq',
#  'tuatapere',
#  'nishihara',
#  'bathsheba',
#  'chuy',
#  'port alfred',
#  'westport',
#  'port macquarie',
#  'bethel',
#  'ribeira grande',
#  'sao joao da barra',
#  'terrace',
#  'ilulissat',
#  'rezina',
#  'thompson',
#  'avarua',
#  'wabrzezno',
#  'korem',
#  'santa cruz',
#  'diamantino',
#  'sharan',
#  'new norfolk',
#  'geraldton',
#  'tabiauea',
#  'turbat',
#  'balimo',
#  'shaowu',
#  'tanout',
#  'dunedin',
#  'de aar',
#  'ampanihy',
#  'hamilton',
#  'prince rupert',
#  'ambon',
#  'kuche',
#  'okhotsk',
#  'nyurba',
#  'sovetskaya',
#  'inuvik',
#  'ardistan',
#  'xining',
#  'shangrao',
#  'les cayes',
#  'mehamn',
#  'holoby',
#  'novikovo',
#  'rikitea',
#  'krasnoselkup',
#  'faanui',
#  'san quintin',
#  'gokul',
#  'nadvoitsy',
#  'umzimvubu',
#  'sorkjosen',
#  'avera',
#  'xuddur',
#  'asau',
#  'ostrovnoy',
#  'neuquen',
#  'watari',
#  'qandala',
#  'masuguru',
#  'leningradskiy',
#  'yeppoon',
#  'bonavista',
#  'rimbey',
#  'egvekinot',
#  'vaitupu',
#  'vardo',
#  'jacqueville',
#  'gazanjyk',
#  'canhotinho',
#  'sayyan',
#  'tyup',
#  'kamsack',
#  'suntar',
#  'north bend',
#  'kaspiyskiy',
#  'malakal',
#  'poyarkovo',
#  'samusu',
#  'sechura',
#  'kroya',
#  'macaboboni',
#  'bilibino',
#  'sur',
#  'manzini',
#  'kruisfontein',
#  'duz',
#  'mattru',
#  'kushima',
#  'cururupu',
#  'acapulco',
#  'cam ranh',
#  'saint george',
#  'torbay',
#  'port lincoln',
#  'sisimiut',
#  'petropavlovsk-kamchatskiy',
#  'pisco',
#  'tidore',
#  'longyearbyen',
#  'mantua',
#  'bambous virieux',
#  'ust-koksa',
#  'paamiut',
#  'hays',
#  'saint-francois',
#  'copacabana',
#  'denpasar',
#  'gigmoto',
#  'sampit',
#  'umea',
#  'lagoa',
#  'tuggurt',
#  'tumannyy',
#  'reykjavik',
#  'washougal',
#  'paramonga',
#  'orda',
#  'bolotnoye',
#  'padang',
#  'chegdomyn',
#  'wajir',
#  'san carlos de bariloche',
#  'lundazi',
#  'port hawkesbury',
#  'dharan',
#  'zemio',
#  'sukabumi',
#  'xinzhou',
#  'sitka',
#  'taoudenni',
#  'rawson',
#  'tuktoyaktuk',
#  'kumi',
#  'jega',
#  'colac',
#  'berlevag',
#  'meyungs',
#  'alice springs',
#  'batagay-alyta',
#  'kudahuvadhoo',
#  'ishigaki',
#  'seoul',
#  'glubokoe',
#  'jequie',
#  'abha',
#  'namibe',
#  'amderma',
#  'passo de camaragibe',
#  'sao filipe',
#  'port hardy',
#  'akyab',
#  'san jose',
#  'muzhi',
#  'mount pleasant',
#  'santo antonio do sudoeste',
#  'tessalit',
#  'chone',
#  'tual',
#  'vao',
#  'shimoda',
#  'dosso',
#  'huarmey',
#  'thinadhoo',
#  'yen bai',
#  'saldanha',
#  'balintore',
#  'batticaloa',
#  'carnarvon',
#  'amboasary',
#  'grand gaube',
#  'porto novo',
#  'sept-iles',
#  'palmeiras de goias',
#  'esso',
#  'labytnangi',
#  'muros',
#  'mandera',
#  'anadyr',
#  'poddorye',
#  'esperance',
#  'panaba',
#  'manzanares',
#  'hami',
#  'flinders',
#  'marawi',
#  'haines junction',
#  'kolondieba',
#  'barsovo',
#  'lavrentiya',
#  'hokitika',
#  'hasaki',
#  'carutapera',
#  'half moon bay',
#  'coquimbo',
#  'baoqing',
#  'kaita',
#  'stromness',
#  'weyburn',
#  'lakatoro',
#  'ciudad bolivar',
#  'los llanos de aridane',
#  'gazli',
#  'kavaratti',
#  'sao jose da coroa grande',
#  'tasbuget',
#  'henties bay',
#  'salinopolis',
#  'vangaindrano',
#  'beringovskiy',
#  'srednekolymsk',
#  'vostok',
#  'guerrero negro',
#  'meulaboh',
#  'grindavik',
#  'lotofaga',
#  'khryashchevka',
#  'airai',
#  'ulkan',
#  'iquique',
#  'vila franca do campo',
#  'ilheus',
#  'nedjo',
#  'fortuna',
#  'del rio',
#  'esil',
#  'manzhouli',
#  'le port',
#  'alexandria',
#  'tsihombe',
#  'brae',
#  'chicama',
#  'richards bay',
#  'kastamonu',
#  'antiguo morelos',
#  'singapore',
#  'tucumcari',
#  'salalah',
#  'vila velha',
#  'port blair',
#  'dalton',
#  'saleaula',
#  'watertown',
#  'fort nelson',
#  'palmas',
#  'louisbourg',
#  'yasothon',
#  'assiniboia',
#  'bonnyville',
#  'shangzhi',
#  'araouane',
#  'geilo',
#  'plettenberg bay',
#  'lompoc',
#  'saint-joseph',
#  'derzhavinsk',
#  'kiri buru',
#  'tarudant',
#  'clyde river',
#  'pangnirtung',
#  'jennings',
#  'smiltene',
#  'margate',
#  'sebring',
#  'lolua',
#  'haverfordwest',
#  'cilegon',
#  'nouakchott',
#  'caravelas',
#  'pringsewu',
#  'attawapiskat',
#  'pevek',
#  'millau',
#  'carauari',
#  'samarai',
#  'lubumbashi',
#  'muravlenko',
#  'husavik',
#  'katsuura',
#  'villamontes',
#  'atherton',
#  'aitape',
#  'isangel',
#  'gorom-gorom',
#  'mrirt',
#  'komsomolskiy',
#  'kupang',
#  'tura',
#  'ketchikan',
#  'amnat charoen',
#  'ouegoa',
#  'lubango',
#  'fevralsk',
#  'champerico',
#  'rafaela',
#  'ixtapa',
#  'camacupa',
#  'maceio',
#  'christiana',
#  'yelizovo',
#  'ust-nera',
#  'nurlat',
#  'barbar',
#  'kavieng',
#  'shuangcheng',
#  'nioki',
#  'boffa',
#  'naze',
#  'hollins',
#  'mizan teferi',
#  'broken hill',
#  'marv dasht',
#  'malanje',
#  'changli',
#  'oranjemund',
#  'kloulklubed',
#  'nemuro',
#  'charsadda',
#  'juba',
#  'bandundu',
#  'chapada dos guimaraes',
#  'margherita',
#  'yashkul',
#  'hearst',
#  'rolim de moura',
#  'dingle',
#  'adre',
#  'te anau',
#  'uvalde',
#  'banjar',
#  'nalobikha',
#  'sioux lookout',
#  'aqtobe',
#  'majalengka',
#  'kolosovka',
#  'kavarna',
#  'bayan',
#  'aleppo',
#  'tela',
#  'san juan',
#  'erdenet',
#  'najran',
#  'illela',
#  'dzhusaly',
#  'pyaozerskiy',
#  'riberalta',
#  'sobolevo',
#  'kungurtug',
#  'mount gambier',
#  'ahipara',
#  'mumford',
#  'praia',
#  'tabuk',
#  'westpunt',
#  'manokwari',
#  'waddan',
#  'great bend',
#  'nokaneng',
#  'wanning',
#  'atasu',
#  'loughrea',
#  'laguna',
#  'birao',
#  'doctor pedro p. pena',
#  'lawrenceburg',
#  'sorvag',
#  'udaipura',
#  'saint-georges',
#  'havoysund',
#  'saint-andre-les-vergers',
#  'is',
#  'meadville',
#  'coahuayana',
#  'dergachi',
#  'buchanan',
#  'nouadhibou',
#  'mahajanga',
#  'stokmarknes',
#  'galabovo',
#  'leh',
#  'solnechnyy',
#  'magadan',
#  'alekseyevsk',
#  'rurrenabaque',
#  'lakeside',
#  'neiafu',
#  'potrero del llano',
#  'det udom',
#  'naantali',
#  'homer',
#  'bagotville',
#  'amga',
#  'port keats',
#  'hunza',
#  'labuhan',
#  'rundu',
#  'karlskoga',
#  'olafsvik',
#  'chimbote',
#  'ouadda',
#  'preobrazheniye',
#  'belmonte',
#  'byumba',
#  'izhevskoye',
#  'ilo',
#  'diego de almagro',
#  'santa maria',
#  'la ronge',
#  'pachperwa',
#  'imbituva',
#  'maghama',
#  'burica',
#  'bandarbeyla',
#  'quesnel',
#  'palmeira',
#  'ust-omchug',
#  'yulara',
#  'vestmannaeyjar',
#  'belaya gora',
#  'broome',
#  'juneau',
#  'mogadishu',
#  'opobo',
#  'kyren',
#  'nicosia',
#  'gisborne',
#  'makubetsu',
#  'kangaatsiaq',
#  'weymouth',
#  'grants',
#  'la orilla',
#  'tacoronte',
#  'rafai',
#  'barbastro',
#  'zhangjiakou',
#  'terrace bay',
#  'eshowe',
#  'rognan',
#  'phangnga',
#  'marsa matruh',
#  'pangkalanbuun',
#  'aripuana',
#  'koslan',
#  'vorontsovka',
#  'tsurib',
#  'yaransk',
#  'tiarei',
#  'cockburn town',
#  'la asuncion',
#  'mnogovershinnyy',
#  'dodola',
#  'rio gallegos',
#  'athabasca',
#  'anar darreh',
#  'yarkovo',
#  'urumqi',
#  'tuntum',
#  'ruteng',
#  'omboue',
#  'dolores',
#  'itarema',
#  'dali',
#  'disna',
#  'atar',
#  'vilyuysk',
#  'cap malheureux',
#  'road town',
#  'verkhnyaya inta',
#  'fonte boa',
#  'severnoye',
#  'gulu',
#  'mongo',
#  'omsukchan',
#  'adrar',
#  'sunland park',
#  'rio grande',
#  'varhaug',
#  'nalut',
#  'korla',
#  'ca mau',
#  'torbat-e jam',
#  'spas-demensk',
#  'kaeo',
#  'san alberto',
#  'kesinga',
#  'souillac',
#  'kununurra',
#  'tateyama',
#  'kamina',
#  'alvorada',
#  'padre bernardo',
#  'sorong',
#  'fairview',
#  'flin flon',
#  'zalantun',
#  'emba',
#  'moose factory',
#  'springfield',
#  'purmerend',
#  'uzhur',
#  'nantucket',
#  'verkhoyansk',
#  'bambanglipuro',
#  'tan an',
#  'huntsville',
#  'manakara',
#  'baruun-urt',
#  'ust-kuyga',
#  'noumea',
#  'waingapu',
#  'uyemskiy',
#  'trnava',
#  'miramar',
#  'camacha',
#  'mvuma',
#  'mahon',
#  'cabo san lucas',
#  'lazaro cardenas',
#  'porto seguro',
#  'ushtobe',
#  'vyazma',
#  'gamba',
#  'alyangula',
#  'pimampiro',
#  'toliary',
#  'arlit',
#  'portsmouth',
#  'mastic beach',
#  'kaihua',
#  'gat',
#  'siauliai',
#  'harper',
#  'chumikan',
#  'pacific grove',
#  'rehoboth',
#  'yuanping',
#  'sao miguel',
#  'gizo',
#  'moranbah',
#  'rodrigues alves',
#  'cuamba',
#  'esna',
#  'gouyave',
#  'ust-kulom',
#  'khani',
#  'brookings',
#  'aklavik',
#  'lopatino',
#  'ruatoria',
#  'cap-aux-meules',
#  'nueva loja',
#  'phuket',
#  'cayenne',
#  'gazimurskiy zavod',
#  'girne',
#  'lichinga',
#  'vanderhoof',
#  'khabary',
#  'hovd',
#  'laurel',
#  'balakhta',
#  'cortez',
#  'san policarpo',
#  'starokostyantyniv',
#  'izhma',
#  'sundsvall',
#  'labutta',
#  'japaratuba',
#  'sonoita',
#  'roald',
#  'chara',
#  'kasama',
#  'vigrestad',
#  'townsville',
#  'zhigansk',
#  'matara',
#  'makaryev',
#  'cabedelo',
#  'abu samrah',
#  'mari-turek',
#  'svetlyy',
#  'portales',
#  'kerteh',
#  'tutin',
#  'taburi',
#  'guekedou',
#  'sahrak',
#  'sopelana',
#  'soyo',
#  'kyenjojo',
#  'marsaxlokk',
#  'santa barbara',
#  'rungata',
#  'emerald',
#  'northam',
#  'gospic',
#  'ascension',
#  'waverley',
#  'niono',
#  'tartus',
#  'zyryanka',
#  'pindushi',
#  'podor',
#  'roebourne',
#  'palana',
#  'oriximina',
#  'blonie',
#  'kampot',
#  'makakilo city',
#  'ekhabi',
#  'dunmore town',
#  'nelson bay',
#  'ahmadpur',
#  'shenjiamen',
#  'constitucion',
#  'kedgwick',
#  'puerto leguizamo',
#  'teknaf',
#  'port lavaca',
#  'aflu']

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
set_count = 1

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | vanimo
# Processing Record 2 of Set 1 | mount isa
# Processing Record 3 of Set 1 | one hundred mile house
# City not found. Skipping...
# Processing Record 4 of Set 1 | saint-pierre
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | zhuji
# Processing Record 9 of Set 1 | libreville
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | chany
# Processing Record 12 of Set 1 | kidal
# Processing Record 13 of Set 1 | nizwa
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | lata
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | san rafael
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | espanola
# Processing Record 20 of Set 1 | lorengau
# Processing Record 21 of Set 1 | norman wells
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | klaksvik
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | puerto madero
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | saskylakh
# Processing Record 30 of Set 1 | waipawa
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | codrington
# Processing Record 33 of Set 1 | angra
# City not found. Skipping...
# Processing Record 34 of Set 1 | bengkulu
# Processing Record 35 of Set 1 | touros
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | bilma
# Processing Record 38 of Set 1 | sadiqabad
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | moba
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | khatanga
# Processing Record 46 of Set 1 | college
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | necochea
# Processing Record 49 of Set 1 | arman
# Processing Record 50 of Set 1 | dubki
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | steenwijk
# Processing Record 3 of Set 2 | castro
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 2 | shubarkuduk
# Processing Record 7 of Set 2 | erenhot
# Processing Record 8 of Set 2 | cherskiy
# Processing Record 9 of Set 2 | provideniya
# Processing Record 10 of Set 2 | nhulunbuy
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 13 of Set 2 | nanortalik
# Processing Record 14 of Set 2 | kaitangata
# Processing Record 15 of Set 2 | grande-riviere
# City not found. Skipping...
# Processing Record 16 of Set 2 | ha tinh
# Processing Record 17 of Set 2 | arraial do cabo
# Processing Record 18 of Set 2 | bay roberts
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | wagga wagga
# Processing Record 21 of Set 2 | narsaq
# Processing Record 22 of Set 2 | sinnamary
# Processing Record 23 of Set 2 | iqaluit
# Processing Record 24 of Set 2 | iberia
# Processing Record 25 of Set 2 | chokurdakh
# Processing Record 26 of Set 2 | talnakh
# Processing Record 27 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 2 | kodiak
# Processing Record 29 of Set 2 | concordia
# Processing Record 30 of Set 2 | san patricio
# Processing Record 31 of Set 2 | georgetown
# Processing Record 32 of Set 2 | nome
# Processing Record 33 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 2 | palmas bellas
# Processing Record 35 of Set 2 | mataura
# Processing Record 36 of Set 2 | qaanaaq
# Processing Record 37 of Set 2 | upernavik
# Processing Record 38 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 2 | penzance
# Processing Record 41 of Set 2 | luderitz
# Processing Record 42 of Set 2 | lasa
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | ponta do sol
# Processing Record 45 of Set 2 | hobyo
# Processing Record 46 of Set 2 | cidreira
# Processing Record 47 of Set 2 | nicoya
# Processing Record 48 of Set 2 | fairbanks
# Processing Record 49 of Set 2 | borgarnes
# Processing Record 50 of Set 2 | dujuma
# City not found. Skipping...
# Processing Record 1 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 3 | ola
# Processing Record 3 of Set 3 | tiksi
# Processing Record 4 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 3 | lebu
# Processing Record 6 of Set 3 | yellowknife
# Processing Record 7 of Set 3 | mayumba
# Processing Record 8 of Set 3 | vaini
# Processing Record 9 of Set 3 | eyl
# Processing Record 10 of Set 3 | severo-kurilsk
# Processing Record 11 of Set 3 | kamaishi
# Processing Record 12 of Set 3 | kahului
# Processing Record 13 of Set 3 | batouri
# Processing Record 14 of Set 3 | caraballeda
# Processing Record 15 of Set 3 | hofn
# Processing Record 16 of Set 3 | kozhva
# Processing Record 17 of Set 3 | nikolskoye
# Processing Record 18 of Set 3 | ancud
# Processing Record 19 of Set 3 | praia da vitoria
# Processing Record 20 of Set 3 | san cristobal
# Processing Record 21 of Set 3 | umm lajj
# Processing Record 22 of Set 3 | vanavara
# Processing Record 23 of Set 3 | faya
# Processing Record 24 of Set 3 | coos bay
# Processing Record 25 of Set 3 | kapaa
# Processing Record 26 of Set 3 | kalanguy
# Processing Record 27 of Set 3 | saint anthony
# Processing Record 28 of Set 3 | portland
# Processing Record 29 of Set 3 | hermanus
# Processing Record 30 of Set 3 | khasan
# Processing Record 31 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 32 of Set 3 | lerwick
# Processing Record 33 of Set 3 | bubaque
# Processing Record 34 of Set 3 | mar del plata
# Processing Record 35 of Set 3 | tasiilaq
# Processing Record 36 of Set 3 | tuatapere
# Processing Record 37 of Set 3 | nishihara
# Processing Record 38 of Set 3 | bathsheba
# Processing Record 39 of Set 3 | chuy
# Processing Record 40 of Set 3 | port alfred
# Processing Record 41 of Set 3 | westport
# Processing Record 42 of Set 3 | port macquarie
# Processing Record 43 of Set 3 | bethel
# Processing Record 44 of Set 3 | ribeira grande
# Processing Record 45 of Set 3 | sao joao da barra
# Processing Record 46 of Set 3 | terrace
# Processing Record 47 of Set 3 | ilulissat
# Processing Record 48 of Set 3 | rezina
# Processing Record 49 of Set 3 | thompson
# Processing Record 50 of Set 3 | avarua
# Processing Record 1 of Set 4 | wabrzezno
# Processing Record 2 of Set 4 | korem
# Processing Record 3 of Set 4 | santa cruz
# Processing Record 4 of Set 4 | diamantino
# Processing Record 5 of Set 4 | sharan
# Processing Record 6 of Set 4 | new norfolk
# Processing Record 7 of Set 4 | geraldton
# Processing Record 8 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 4 | turbat
# Processing Record 10 of Set 4 | balimo
# City not found. Skipping...
# Processing Record 11 of Set 4 | shaowu
# Processing Record 12 of Set 4 | tanout
# Processing Record 13 of Set 4 | dunedin
# Processing Record 14 of Set 4 | de aar
# Processing Record 15 of Set 4 | ampanihy
# Processing Record 16 of Set 4 | hamilton
# Processing Record 17 of Set 4 | prince rupert
# Processing Record 18 of Set 4 | ambon
# Processing Record 19 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 4 | okhotsk
# Processing Record 21 of Set 4 | nyurba
# Processing Record 22 of Set 4 | sovetskaya
# Processing Record 23 of Set 4 | inuvik
# Processing Record 24 of Set 4 | ardistan
# City not found. Skipping...
# Processing Record 25 of Set 4 | xining
# Processing Record 26 of Set 4 | shangrao
# Processing Record 27 of Set 4 | les cayes
# Processing Record 28 of Set 4 | mehamn
# Processing Record 29 of Set 4 | holoby
# Processing Record 30 of Set 4 | novikovo
# Processing Record 31 of Set 4 | rikitea
# Processing Record 32 of Set 4 | krasnoselkup
# Processing Record 33 of Set 4 | faanui
# Processing Record 34 of Set 4 | san quintin
# Processing Record 35 of Set 4 | gokul
# Processing Record 36 of Set 4 | nadvoitsy
# Processing Record 37 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 4 | sorkjosen
# Processing Record 39 of Set 4 | avera
# Processing Record 40 of Set 4 | xuddur
# Processing Record 41 of Set 4 | asau
# Processing Record 42 of Set 4 | ostrovnoy
# Processing Record 43 of Set 4 | neuquen
# Processing Record 44 of Set 4 | watari
# Processing Record 45 of Set 4 | qandala
# Processing Record 46 of Set 4 | masuguru
# Processing Record 47 of Set 4 | leningradskiy
# Processing Record 48 of Set 4 | yeppoon
# Processing Record 49 of Set 4 | bonavista
# Processing Record 50 of Set 4 | rimbey
# Processing Record 1 of Set 5 | egvekinot
# Processing Record 2 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 5 | vardo
# Processing Record 4 of Set 5 | jacqueville
# Processing Record 5 of Set 5 | gazanjyk
# Processing Record 6 of Set 5 | canhotinho
# Processing Record 7 of Set 5 | sayyan
# Processing Record 8 of Set 5 | tyup
# Processing Record 9 of Set 5 | kamsack
# Processing Record 10 of Set 5 | suntar
# Processing Record 11 of Set 5 | north bend
# Processing Record 12 of Set 5 | kaspiyskiy
# Processing Record 13 of Set 5 | malakal
# Processing Record 14 of Set 5 | poyarkovo
# Processing Record 15 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 5 | sechura
# Processing Record 17 of Set 5 | kroya
# Processing Record 18 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 19 of Set 5 | bilibino
# Processing Record 20 of Set 5 | sur
# Processing Record 21 of Set 5 | manzini
# Processing Record 22 of Set 5 | kruisfontein
# Processing Record 23 of Set 5 | duz
# City not found. Skipping...
# Processing Record 24 of Set 5 | mattru
# Processing Record 25 of Set 5 | kushima
# Processing Record 26 of Set 5 | cururupu
# Processing Record 27 of Set 5 | acapulco
# Processing Record 28 of Set 5 | cam ranh
# Processing Record 29 of Set 5 | saint george
# Processing Record 30 of Set 5 | torbay
# Processing Record 31 of Set 5 | port lincoln
# Processing Record 32 of Set 5 | sisimiut
# Processing Record 33 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 5 | pisco
# Processing Record 35 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 36 of Set 5 | longyearbyen
# Processing Record 37 of Set 5 | mantua
# Processing Record 38 of Set 5 | bambous virieux
# Processing Record 39 of Set 5 | ust-koksa
# Processing Record 40 of Set 5 | paamiut
# Processing Record 41 of Set 5 | hays
# Processing Record 42 of Set 5 | saint-francois
# Processing Record 43 of Set 5 | copacabana
# Processing Record 44 of Set 5 | denpasar
# Processing Record 45 of Set 5 | gigmoto
# Processing Record 46 of Set 5 | sampit
# Processing Record 47 of Set 5 | umea
# Processing Record 48 of Set 5 | lagoa
# Processing Record 49 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 50 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 6 | reykjavik
# Processing Record 2 of Set 6 | washougal
# Processing Record 3 of Set 6 | paramonga
# Processing Record 4 of Set 6 | orda
# Processing Record 5 of Set 6 | bolotnoye
# Processing Record 6 of Set 6 | padang
# Processing Record 7 of Set 6 | chegdomyn
# Processing Record 8 of Set 6 | wajir
# Processing Record 9 of Set 6 | san carlos de bariloche
# Processing Record 10 of Set 6 | lundazi
# Processing Record 11 of Set 6 | port hawkesbury
# Processing Record 12 of Set 6 | dharan
# Processing Record 13 of Set 6 | zemio
# Processing Record 14 of Set 6 | sukabumi
# Processing Record 15 of Set 6 | xinzhou
# Processing Record 16 of Set 6 | sitka
# Processing Record 17 of Set 6 | taoudenni
# Processing Record 18 of Set 6 | rawson
# Processing Record 19 of Set 6 | tuktoyaktuk
# Processing Record 20 of Set 6 | kumi
# Processing Record 21 of Set 6 | jega
# Processing Record 22 of Set 6 | colac
# Processing Record 23 of Set 6 | berlevag
# Processing Record 24 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 6 | alice springs
# Processing Record 26 of Set 6 | batagay-alyta
# Processing Record 27 of Set 6 | kudahuvadhoo
# Processing Record 28 of Set 6 | ishigaki
# Processing Record 29 of Set 6 | seoul
# Processing Record 30 of Set 6 | glubokoe
# City not found. Skipping...
# Processing Record 31 of Set 6 | jequie
# Processing Record 32 of Set 6 | abha
# Processing Record 33 of Set 6 | namibe
# Processing Record 34 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 6 | passo de camaragibe
# Processing Record 36 of Set 6 | sao filipe
# Processing Record 37 of Set 6 | port hardy
# Processing Record 38 of Set 6 | akyab
# Processing Record 39 of Set 6 | san jose
# Processing Record 40 of Set 6 | muzhi
# Processing Record 41 of Set 6 | mount pleasant
# Processing Record 42 of Set 6 | santo antonio do sudoeste
# Processing Record 43 of Set 6 | tessalit
# Processing Record 44 of Set 6 | chone
# Processing Record 45 of Set 6 | tual
# Processing Record 46 of Set 6 | vao
# Processing Record 47 of Set 6 | shimoda
# Processing Record 48 of Set 6 | dosso
# Processing Record 49 of Set 6 | huarmey
# Processing Record 50 of Set 6 | thinadhoo
# Processing Record 1 of Set 7 | yen bai
# Processing Record 2 of Set 7 | saldanha
# Processing Record 3 of Set 7 | balintore
# Processing Record 4 of Set 7 | batticaloa
# Processing Record 5 of Set 7 | carnarvon
# Processing Record 6 of Set 7 | amboasary
# Processing Record 7 of Set 7 | grand gaube
# Processing Record 8 of Set 7 | porto novo
# Processing Record 9 of Set 7 | sept-iles
# Processing Record 10 of Set 7 | palmeiras de goias
# Processing Record 11 of Set 7 | esso
# Processing Record 12 of Set 7 | labytnangi
# Processing Record 13 of Set 7 | muros
# Processing Record 14 of Set 7 | mandera
# Processing Record 15 of Set 7 | anadyr
# Processing Record 16 of Set 7 | poddorye
# Processing Record 17 of Set 7 | esperance
# Processing Record 18 of Set 7 | panaba
# Processing Record 19 of Set 7 | manzanares
# Processing Record 20 of Set 7 | hami
# Processing Record 21 of Set 7 | flinders
# Processing Record 22 of Set 7 | marawi
# Processing Record 23 of Set 7 | haines junction
# Processing Record 24 of Set 7 | kolondieba
# Processing Record 25 of Set 7 | barsovo
# Processing Record 26 of Set 7 | lavrentiya
# Processing Record 27 of Set 7 | hokitika
# Processing Record 28 of Set 7 | hasaki
# Processing Record 29 of Set 7 | carutapera
# Processing Record 30 of Set 7 | half moon bay
# Processing Record 31 of Set 7 | coquimbo
# Processing Record 32 of Set 7 | baoqing
# Processing Record 33 of Set 7 | kaita
# Processing Record 34 of Set 7 | stromness
# Processing Record 35 of Set 7 | weyburn
# Processing Record 36 of Set 7 | lakatoro
# Processing Record 37 of Set 7 | ciudad bolivar
# Processing Record 38 of Set 7 | los llanos de aridane
# Processing Record 39 of Set 7 | gazli
# Processing Record 40 of Set 7 | kavaratti
# Processing Record 41 of Set 7 | sao jose da coroa grande
# Processing Record 42 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 43 of Set 7 | henties bay
# Processing Record 44 of Set 7 | salinopolis
# Processing Record 45 of Set 7 | vangaindrano
# Processing Record 46 of Set 7 | beringovskiy
# Processing Record 47 of Set 7 | srednekolymsk
# Processing Record 48 of Set 7 | vostok
# Processing Record 49 of Set 7 | guerrero negro
# Processing Record 50 of Set 7 | meulaboh
# Processing Record 1 of Set 8 | grindavik
# Processing Record 2 of Set 8 | lotofaga
# Processing Record 3 of Set 8 | khryashchevka
# Processing Record 4 of Set 8 | airai
# Processing Record 5 of Set 8 | ulkan
# Processing Record 6 of Set 8 | iquique
# Processing Record 7 of Set 8 | vila franca do campo
# Processing Record 8 of Set 8 | ilheus
# Processing Record 9 of Set 8 | nedjo
# Processing Record 10 of Set 8 | fortuna
# Processing Record 11 of Set 8 | del rio
# Processing Record 12 of Set 8 | esil
# Processing Record 13 of Set 8 | manzhouli
# Processing Record 14 of Set 8 | le port
# Processing Record 15 of Set 8 | alexandria
# Processing Record 16 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 8 | brae
# Processing Record 18 of Set 8 | chicama
# Processing Record 19 of Set 8 | richards bay
# Processing Record 20 of Set 8 | kastamonu
# Processing Record 21 of Set 8 | antiguo morelos
# Processing Record 22 of Set 8 | singapore
# Processing Record 23 of Set 8 | tucumcari
# Processing Record 24 of Set 8 | salalah
# Processing Record 25 of Set 8 | vila velha
# Processing Record 26 of Set 8 | port blair
# Processing Record 27 of Set 8 | dalton
# Processing Record 28 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 8 | watertown
# Processing Record 30 of Set 8 | fort nelson
# Processing Record 31 of Set 8 | palmas
# Processing Record 32 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 8 | yasothon
# Processing Record 34 of Set 8 | assiniboia
# Processing Record 35 of Set 8 | bonnyville
# Processing Record 36 of Set 8 | shangzhi
# Processing Record 37 of Set 8 | araouane
# Processing Record 38 of Set 8 | geilo
# Processing Record 39 of Set 8 | plettenberg bay
# Processing Record 40 of Set 8 | lompoc
# Processing Record 41 of Set 8 | saint-joseph
# Processing Record 42 of Set 8 | derzhavinsk
# Processing Record 43 of Set 8 | kiri buru
# Processing Record 44 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 45 of Set 8 | clyde river
# Processing Record 46 of Set 8 | pangnirtung
# Processing Record 47 of Set 8 | jennings
# Processing Record 48 of Set 8 | smiltene
# Processing Record 49 of Set 8 | margate
# Processing Record 50 of Set 8 | sebring
# Processing Record 1 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 9 | haverfordwest
# Processing Record 3 of Set 9 | cilegon
# Processing Record 4 of Set 9 | nouakchott
# Processing Record 5 of Set 9 | caravelas
# Processing Record 6 of Set 9 | pringsewu
# Processing Record 7 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 9 | pevek
# Processing Record 9 of Set 9 | millau
# Processing Record 10 of Set 9 | carauari
# Processing Record 11 of Set 9 | samarai
# Processing Record 12 of Set 9 | lubumbashi
# Processing Record 13 of Set 9 | muravlenko
# Processing Record 14 of Set 9 | husavik
# Processing Record 15 of Set 9 | katsuura
# Processing Record 16 of Set 9 | villamontes
# Processing Record 17 of Set 9 | atherton
# Processing Record 18 of Set 9 | aitape
# Processing Record 19 of Set 9 | isangel
# Processing Record 20 of Set 9 | gorom-gorom
# Processing Record 21 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 9 | komsomolskiy
# Processing Record 23 of Set 9 | kupang
# Processing Record 24 of Set 9 | tura
# Processing Record 25 of Set 9 | ketchikan
# Processing Record 26 of Set 9 | amnat charoen
# Processing Record 27 of Set 9 | ouegoa
# Processing Record 28 of Set 9 | lubango
# Processing Record 29 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 30 of Set 9 | champerico
# Processing Record 31 of Set 9 | rafaela
# Processing Record 32 of Set 9 | ixtapa
# Processing Record 33 of Set 9 | camacupa
# Processing Record 34 of Set 9 | maceio
# Processing Record 35 of Set 9 | christiana
# Processing Record 36 of Set 9 | yelizovo
# Processing Record 37 of Set 9 | ust-nera
# Processing Record 38 of Set 9 | nurlat
# Processing Record 39 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 40 of Set 9 | kavieng
# Processing Record 41 of Set 9 | shuangcheng
# Processing Record 42 of Set 9 | nioki
# Processing Record 43 of Set 9 | boffa
# Processing Record 44 of Set 9 | naze
# Processing Record 45 of Set 9 | hollins
# Processing Record 46 of Set 9 | mizan teferi
# Processing Record 47 of Set 9 | broken hill
# Processing Record 48 of Set 9 | marv dasht
# City not found. Skipping...
# Processing Record 49 of Set 9 | malanje
# Processing Record 50 of Set 9 | changli
# Processing Record 1 of Set 10 | oranjemund
# Processing Record 2 of Set 10 | kloulklubed
# Processing Record 3 of Set 10 | nemuro
# Processing Record 4 of Set 10 | charsadda
# Processing Record 5 of Set 10 | juba
# Processing Record 6 of Set 10 | bandundu
# Processing Record 7 of Set 10 | chapada dos guimaraes
# Processing Record 8 of Set 10 | margherita
# Processing Record 9 of Set 10 | yashkul
# Processing Record 10 of Set 10 | hearst
# Processing Record 11 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 12 of Set 10 | dingle
# Processing Record 13 of Set 10 | adre
# Processing Record 14 of Set 10 | te anau
# Processing Record 15 of Set 10 | uvalde
# Processing Record 16 of Set 10 | banjar
# Processing Record 17 of Set 10 | nalobikha
# Processing Record 18 of Set 10 | sioux lookout
# Processing Record 19 of Set 10 | aqtobe
# Processing Record 20 of Set 10 | majalengka
# Processing Record 21 of Set 10 | kolosovka
# Processing Record 22 of Set 10 | kavarna
# Processing Record 23 of Set 10 | bayan
# Processing Record 24 of Set 10 | aleppo
# Processing Record 25 of Set 10 | tela
# Processing Record 26 of Set 10 | san juan
# Processing Record 27 of Set 10 | erdenet
# Processing Record 28 of Set 10 | najran
# Processing Record 29 of Set 10 | illela
# Processing Record 30 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 31 of Set 10 | pyaozerskiy
# Processing Record 32 of Set 10 | riberalta
# Processing Record 33 of Set 10 | sobolevo
# Processing Record 34 of Set 10 | kungurtug
# Processing Record 35 of Set 10 | mount gambier
# Processing Record 36 of Set 10 | ahipara
# Processing Record 37 of Set 10 | mumford
# Processing Record 38 of Set 10 | praia
# Processing Record 39 of Set 10 | tabuk
# Processing Record 40 of Set 10 | westpunt
# City not found. Skipping...
# Processing Record 41 of Set 10 | manokwari
# Processing Record 42 of Set 10 | waddan
# Processing Record 43 of Set 10 | great bend
# Processing Record 44 of Set 10 | nokaneng
# Processing Record 45 of Set 10 | wanning
# Processing Record 46 of Set 10 | atasu
# Processing Record 47 of Set 10 | loughrea
# Processing Record 48 of Set 10 | laguna
# Processing Record 49 of Set 10 | birao
# Processing Record 50 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 1 of Set 11 | lawrenceburg
# Processing Record 2 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 11 | udaipura
# Processing Record 4 of Set 11 | saint-georges
# Processing Record 5 of Set 11 | havoysund
# Processing Record 6 of Set 11 | saint-andre-les-vergers
# Processing Record 7 of Set 11 | is
# City not found. Skipping...
# Processing Record 8 of Set 11 | meadville
# Processing Record 9 of Set 11 | coahuayana
# Processing Record 10 of Set 11 | dergachi
# Processing Record 11 of Set 11 | buchanan
# Processing Record 12 of Set 11 | nouadhibou
# Processing Record 13 of Set 11 | mahajanga
# Processing Record 14 of Set 11 | stokmarknes
# Processing Record 15 of Set 11 | galabovo
# Processing Record 16 of Set 11 | leh
# Processing Record 17 of Set 11 | solnechnyy
# Processing Record 18 of Set 11 | magadan
# Processing Record 19 of Set 11 | alekseyevsk
# Processing Record 20 of Set 11 | rurrenabaque
# Processing Record 21 of Set 11 | lakeside
# Processing Record 22 of Set 11 | neiafu
# Processing Record 23 of Set 11 | potrero del llano
# Processing Record 24 of Set 11 | det udom
# Processing Record 25 of Set 11 | naantali
# Processing Record 26 of Set 11 | homer
# Processing Record 27 of Set 11 | bagotville
# Processing Record 28 of Set 11 | amga
# Processing Record 29 of Set 11 | port keats
# Processing Record 30 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 31 of Set 11 | labuhan
# Processing Record 32 of Set 11 | rundu
# Processing Record 33 of Set 11 | karlskoga
# Processing Record 34 of Set 11 | olafsvik
# Processing Record 35 of Set 11 | chimbote
# Processing Record 36 of Set 11 | ouadda
# Processing Record 37 of Set 11 | preobrazheniye
# Processing Record 38 of Set 11 | belmonte
# Processing Record 39 of Set 11 | byumba
# Processing Record 40 of Set 11 | izhevskoye
# Processing Record 41 of Set 11 | ilo
# Processing Record 42 of Set 11 | diego de almagro
# Processing Record 43 of Set 11 | santa maria
# Processing Record 44 of Set 11 | la ronge
# Processing Record 45 of Set 11 | pachperwa
# Processing Record 46 of Set 11 | imbituva
# Processing Record 47 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 48 of Set 11 | burica
# City not found. Skipping...
# Processing Record 49 of Set 11 | bandarbeyla
# Processing Record 50 of Set 11 | quesnel
# Processing Record 1 of Set 12 | palmeira
# Processing Record 2 of Set 12 | ust-omchug
# Processing Record 3 of Set 12 | yulara
# Processing Record 4 of Set 12 | vestmannaeyjar
# Processing Record 5 of Set 12 | belaya gora
# Processing Record 6 of Set 12 | broome
# Processing Record 7 of Set 12 | juneau
# Processing Record 8 of Set 12 | mogadishu
# Processing Record 9 of Set 12 | opobo
# City not found. Skipping...
# Processing Record 10 of Set 12 | kyren
# Processing Record 11 of Set 12 | nicosia
# Processing Record 12 of Set 12 | gisborne
# Processing Record 13 of Set 12 | makubetsu
# Processing Record 14 of Set 12 | kangaatsiaq
# Processing Record 15 of Set 12 | weymouth
# Processing Record 16 of Set 12 | grants
# Processing Record 17 of Set 12 | la orilla
# Processing Record 18 of Set 12 | tacoronte
# Processing Record 19 of Set 12 | rafai
# Processing Record 20 of Set 12 | barbastro
# Processing Record 21 of Set 12 | zhangjiakou
# Processing Record 22 of Set 12 | terrace bay
# Processing Record 23 of Set 12 | eshowe
# Processing Record 24 of Set 12 | rognan
# Processing Record 25 of Set 12 | phangnga
# Processing Record 26 of Set 12 | marsa matruh
# Processing Record 27 of Set 12 | pangkalanbuun
# Processing Record 28 of Set 12 | aripuana
# Processing Record 29 of Set 12 | koslan
# Processing Record 30 of Set 12 | vorontsovka
# Processing Record 31 of Set 12 | tsurib
# Processing Record 32 of Set 12 | yaransk
# Processing Record 33 of Set 12 | tiarei
# Processing Record 34 of Set 12 | cockburn town
# Processing Record 35 of Set 12 | la asuncion
# Processing Record 36 of Set 12 | mnogovershinnyy
# Processing Record 37 of Set 12 | dodola
# Processing Record 38 of Set 12 | rio gallegos
# Processing Record 39 of Set 12 | athabasca
# Processing Record 40 of Set 12 | anar darreh
# City not found. Skipping...
# Processing Record 41 of Set 12 | yarkovo
# Processing Record 42 of Set 12 | urumqi
# Processing Record 43 of Set 12 | tuntum
# Processing Record 44 of Set 12 | ruteng
# Processing Record 45 of Set 12 | omboue
# Processing Record 46 of Set 12 | dolores
# Processing Record 47 of Set 12 | itarema
# Processing Record 48 of Set 12 | dali
# Processing Record 49 of Set 12 | disna
# Processing Record 50 of Set 12 | atar
# Processing Record 1 of Set 13 | vilyuysk
# Processing Record 2 of Set 13 | cap malheureux
# Processing Record 3 of Set 13 | road town
# Processing Record 4 of Set 13 | verkhnyaya inta
# Processing Record 5 of Set 13 | fonte boa
# Processing Record 6 of Set 13 | severnoye
# Processing Record 7 of Set 13 | gulu
# Processing Record 8 of Set 13 | mongo
# Processing Record 9 of Set 13 | omsukchan
# Processing Record 10 of Set 13 | adrar
# Processing Record 11 of Set 13 | sunland park
# Processing Record 12 of Set 13 | rio grande
# Processing Record 13 of Set 13 | varhaug
# Processing Record 14 of Set 13 | nalut
# Processing Record 15 of Set 13 | korla
# Processing Record 16 of Set 13 | ca mau
# Processing Record 17 of Set 13 | torbat-e jam
# Processing Record 18 of Set 13 | spas-demensk
# Processing Record 19 of Set 13 | kaeo
# Processing Record 20 of Set 13 | san alberto
# Processing Record 21 of Set 13 | kesinga
# Processing Record 22 of Set 13 | souillac
# Processing Record 23 of Set 13 | kununurra
# Processing Record 24 of Set 13 | tateyama
# Processing Record 25 of Set 13 | kamina
# Processing Record 26 of Set 13 | alvorada
# Processing Record 27 of Set 13 | padre bernardo
# Processing Record 28 of Set 13 | sorong
# Processing Record 29 of Set 13 | fairview
# Processing Record 30 of Set 13 | flin flon
# Processing Record 31 of Set 13 | zalantun
# Processing Record 32 of Set 13 | emba
# Processing Record 33 of Set 13 | moose factory
# Processing Record 34 of Set 13 | springfield
# Processing Record 35 of Set 13 | purmerend
# Processing Record 36 of Set 13 | uzhur
# Processing Record 37 of Set 13 | nantucket
# Processing Record 38 of Set 13 | verkhoyansk
# Processing Record 39 of Set 13 | bambanglipuro
# Processing Record 40 of Set 13 | tan an
# Processing Record 41 of Set 13 | huntsville
# Processing Record 42 of Set 13 | manakara
# Processing Record 43 of Set 13 | baruun-urt
# Processing Record 44 of Set 13 | ust-kuyga
# Processing Record 45 of Set 13 | noumea
# Processing Record 46 of Set 13 | waingapu
# Processing Record 47 of Set 13 | uyemskiy
# Processing Record 48 of Set 13 | trnava
# Processing Record 49 of Set 13 | miramar
# Processing Record 50 of Set 13 | camacha
# Processing Record 1 of Set 14 | mvuma
# Processing Record 2 of Set 14 | mahon
# Processing Record 3 of Set 14 | cabo san lucas
# Processing Record 4 of Set 14 | lazaro cardenas
# Processing Record 5 of Set 14 | porto seguro
# Processing Record 6 of Set 14 | ushtobe
# Processing Record 7 of Set 14 | vyazma
# Processing Record 8 of Set 14 | gamba
# Processing Record 9 of Set 14 | alyangula
# Processing Record 10 of Set 14 | pimampiro
# Processing Record 11 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 14 | arlit
# Processing Record 13 of Set 14 | portsmouth
# Processing Record 14 of Set 14 | mastic beach
# Processing Record 15 of Set 14 | kaihua
# Processing Record 16 of Set 14 | gat
# Processing Record 17 of Set 14 | siauliai
# Processing Record 18 of Set 14 | harper
# Processing Record 19 of Set 14 | chumikan
# Processing Record 20 of Set 14 | pacific grove
# Processing Record 21 of Set 14 | rehoboth
# Processing Record 22 of Set 14 | yuanping
# Processing Record 23 of Set 14 | sao miguel
# Processing Record 24 of Set 14 | gizo
# Processing Record 25 of Set 14 | moranbah
# Processing Record 26 of Set 14 | rodrigues alves
# Processing Record 27 of Set 14 | cuamba
# Processing Record 28 of Set 14 | esna
# Processing Record 29 of Set 14 | gouyave
# Processing Record 30 of Set 14 | ust-kulom
# Processing Record 31 of Set 14 | khani
# Processing Record 32 of Set 14 | brookings
# Processing Record 33 of Set 14 | aklavik
# Processing Record 34 of Set 14 | lopatino
# Processing Record 35 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 14 | cap-aux-meules
# Processing Record 37 of Set 14 | nueva loja
# Processing Record 38 of Set 14 | phuket
# Processing Record 39 of Set 14 | cayenne
# Processing Record 40 of Set 14 | gazimurskiy zavod
# Processing Record 41 of Set 14 | girne
# Processing Record 42 of Set 14 | lichinga
# Processing Record 43 of Set 14 | vanderhoof
# Processing Record 44 of Set 14 | khabary
# Processing Record 45 of Set 14 | hovd
# Processing Record 46 of Set 14 | laurel
# Processing Record 47 of Set 14 | balakhta
# Processing Record 48 of Set 14 | cortez
# Processing Record 49 of Set 14 | san policarpo
# Processing Record 50 of Set 14 | starokostyantyniv
# Processing Record 1 of Set 15 | izhma
# Processing Record 2 of Set 15 | sundsvall
# Processing Record 3 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 4 of Set 15 | japaratuba
# Processing Record 5 of Set 15 | sonoita
# Processing Record 6 of Set 15 | roald
# Processing Record 7 of Set 15 | chara
# Processing Record 8 of Set 15 | kasama
# Processing Record 9 of Set 15 | vigrestad
# Processing Record 10 of Set 15 | townsville
# Processing Record 11 of Set 15 | zhigansk
# Processing Record 12 of Set 15 | matara
# Processing Record 13 of Set 15 | makaryev
# Processing Record 14 of Set 15 | cabedelo
# Processing Record 15 of Set 15 | abu samrah
# Processing Record 16 of Set 15 | mari-turek
# Processing Record 17 of Set 15 | svetlyy
# Processing Record 18 of Set 15 | portales
# Processing Record 19 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 20 of Set 15 | tutin
# Processing Record 21 of Set 15 | taburi
# City not found. Skipping...
# Processing Record 22 of Set 15 | guekedou
# City not found. Skipping...
# Processing Record 23 of Set 15 | sahrak
# City not found. Skipping...
# Processing Record 24 of Set 15 | sopelana
# Processing Record 25 of Set 15 | soyo
# Processing Record 26 of Set 15 | kyenjojo
# Processing Record 27 of Set 15 | marsaxlokk
# Processing Record 28 of Set 15 | santa barbara
# Processing Record 29 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 15 | emerald
# Processing Record 31 of Set 15 | northam
# Processing Record 32 of Set 15 | gospic
# Processing Record 33 of Set 15 | ascension
# Processing Record 34 of Set 15 | waverley
# Processing Record 35 of Set 15 | niono
# Processing Record 36 of Set 15 | tartus
# Processing Record 37 of Set 15 | zyryanka
# Processing Record 38 of Set 15 | pindushi
# Processing Record 39 of Set 15 | podor
# Processing Record 40 of Set 15 | roebourne
# Processing Record 41 of Set 15 | palana
# Processing Record 42 of Set 15 | oriximina
# Processing Record 43 of Set 15 | blonie
# Processing Record 44 of Set 15 | kampot
# Processing Record 45 of Set 15 | makakilo city
# Processing Record 46 of Set 15 | ekhabi
# Processing Record 47 of Set 15 | dunmore town
# Processing Record 48 of Set 15 | nelson bay
# Processing Record 49 of Set 15 | ahmadpur
# Processing Record 50 of Set 15 | shenjiamen
# Processing Record 1 of Set 16 | constitucion
# Processing Record 2 of Set 16 | kedgwick
# Processing Record 3 of Set 16 | puerto leguizamo
# Processing Record 4 of Set 16 | teknaf
# Processing Record 5 of Set 16 | port lavaca
# Processing Record 6 of Set 16 | aflu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 693

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Vanimo  -2.6741  141.3028     86.18        68          94
# 1     Mount Isa -20.7333  139.5000    103.77        13          40
# 2  Saint-Pierre -21.3393   55.4781     76.68        57           0
# 3          Hilo  19.7297 -155.0900     74.93        86          90
# 4         Zhuji  29.7188  120.2423     66.88        58          98
# 5    Libreville   0.3925    9.4537     77.02       100          75
# 6       Ushuaia -54.8000  -68.3000     42.46        65          20
# 7         Chany  55.3121   76.7647     46.53        70          94
# 8         Kidal  18.4411    1.4078     80.76        39          16
# 9         Nizwa  22.9333   57.5333     83.17        20           6
#
#    Wind Speed Country Current Description
# 0        9.95      PG     overcast clouds
# 1        5.75      AU    scattered clouds
# 2        4.61      RE           clear sky
# 3        5.75      US     overcast clouds
# 4        6.67      CN     overcast clouds
# 5        9.22      GA       moderate rain
# 6        5.75      AR          few clouds
# 7        7.87      RU     overcast clouds
# 8        3.56      ML          few clouds
# 9        0.22      OM           clear sky

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Vanimo      PG  -2.6741  141.3028     86.18        68
# 1           Mount Isa      AU -20.7333  139.5000    103.77        13
# 2        Saint-Pierre      RE -21.3393   55.4781     76.68        57
# 3                Hilo      US  19.7297 -155.0900     74.93        86
# 4               Zhuji      CN  29.7188  120.2423     66.88        58
# ..                ...     ...      ...       ...       ...       ...
# 688      Constitucion      CL -35.3333  -72.4167     56.21        67
# 689          Kedgwick      CA  47.6446  -67.3434     40.26        93
# 690  Puerto Leguizamo      CO  -0.1934  -74.7819     71.20        97
# 691            Teknaf      BD  20.8624   92.3058     84.56        76
# 692       Port Lavaca      US  28.6150  -96.6261     68.05        82
#
#      Cloudiness  Wind Speed Current Description
# 0            94        9.95     overcast clouds
# 1            40        5.75    scattered clouds
# 2             0        4.61           clear sky
# 3            90        5.75     overcast clouds
# 4            98        6.67     overcast clouds
# ..          ...         ...                 ...
# 688           0        6.04           clear sky
# 689         100       10.00     overcast clouds
# 690          84        1.88       broken clouds
# 691          98       10.76     overcast clouds
# 692           1        6.91           clear sky
#
# [693 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
